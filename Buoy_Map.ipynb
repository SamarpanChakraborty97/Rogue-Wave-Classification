# %%
import pandas as pd
import numpy as np
import folium

# %%
buoy_info = pd.read_csv("buoy_information.csv", header = None)

# %%
buoy_info.columns = ['buoy_name','depth','latitude','longitude']

# %%
buoy_info['buoy_name'] = buoy_info['buoy_name'].astype(int)

# %%
buoy_info.head(20)
# Out:
#     buoy_name       depth   latitude   longitude
# 0          28  366.501820  33.854929 -118.633477
# 1          29  549.913747  37.945814 -123.469251
# 2          36   40.146470  46.857478 -124.244542
# 3          43   20.000000  33.219940 -117.439445
# 4          45  225.587692  33.178806 -117.471486
# 5          67  288.285001  33.223483 -119.864341
# 6          71  476.349102  34.459735 -120.765927
# 7          76   25.496539  35.205726 -120.859604
# 8          81   53.000000  34.180000 -119.476669
# 9          87   35.000000  34.038334 -120.091667
# 10         88   55.000000  34.070000 -119.833336
# 11         89   55.000000  34.058334 -119.583336
# 12         90   61.000000  34.325001 -119.641670
# 13         91  182.352003  32.631844 -117.444068
# 14         92  432.135652  33.613898 -118.312238
# 15         93  188.968928  32.745832 -117.369096
# 16         94  328.042775  40.293043 -124.736832
# 17         95  180.011431  32.850571 -117.350999
# 18         96  369.750000  33.458447 -117.767031
# 19         97  120.000000  21.233334 -157.796661

# %%
buoy_info_array = np.asarray(buoy_info)

# %%
# buoy_info_array

# %%
us_center_latitude = 39.8281757358
us_center_longitude = -98.579500000

east_coast_focused_latitude = 40.71277600000
east_coast_focused_longitude = -74.005974000000

west_coast_focused_latitude = 37.77492900000
west_coast_focused_longitude = -122.41941800000


# Create a map centered at the given coordinates with a specific zoom level
# my_map = folium.Map(location=[us_center_latitude, us_center_longitude], zoom_start=5)  #### us center
# my_map = folium.Map(location=[east_coast_focused_latitude, east_coast_focused_longitude], zoom_start=5)  #### east coast center
my_map = folium.Map(location=[west_coast_focused_latitude, west_coast_focused_longitude], zoom_start=5)  #### west coast center

# List of coordinates
buoy_properties = []
for i in range(buoy_info_array.shape[0]):
    buoy_prop = (buoy_info_array[i][0], buoy_info_array[i][1], buoy_info_array[i][2], buoy_info_array[i][3])
    buoy_properties.append(buoy_prop)
    
# Add markers to the map
for entry in buoy_properties:
    
    buoy_num = entry[0]
    depth = entry[1]
    latitude = entry[2]
    longitude = entry[3]

    if depth < 20:
        color = "red"
        classification = "shallow"
    elif 20 <= depth <= 100:
        color = "orange"
        classification = "intermediate"
    else:
        color = "blue"
        classification = "deep"

    
    folium.Marker(
        location=[latitude, longitude],
        popup=folium.Popup(f'Buoy_number: {buoy_num.astype(int)}\n Depth: {classification}', parse_html=True),
        icon=folium.Icon(color=color)
    ).add_to(my_map)

# Save the map to an HTML file
my_map.save("west_coast_focused_buoys.html")

# %%
my_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0e40779e47dda69496df59b773841f4f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0e40779e47dda69496df59b773841f4f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0e40779e47dda69496df59b773841f4f = L.map(
#                 &quot;map_0e40779e47dda69496df59b773841f4f&quot;,
#                 {
#                     center: [37.774929, -122.419418],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_918b77743b79908aad8967f4f20a6281 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_918b77743b79908aad8967f4f20a6281.addTo(map_0e40779e47dda69496df59b773841f4f);
#
#
#             var marker_251f6cade78b6b604342e03818ceeffb = L.marker(
#                 [33.854928796941586, -118.6334772976962],
#                 {}
#             ).addTo(map_0e40779e47dda69496df59b773841f4f);
#
#
#             var icon_88273cd21431cb1bcf233ef9f27395eb = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_251f6cade78b6b604342e03818ceeffb.setIcon(icon_88273cd21431cb1bcf233ef9f27395eb);
#
#
#         var popup_7f214a7ba3fac60bd62faffa8615a4c7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c63153ab432f25fa314d7522d50a7334 = $(`&lt;div id=&quot;html_c63153ab432f25fa314d7522d50a7334&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Buoy_number: 28  Depth: deep&lt;/div&gt;`)[0];
#                 popup_7f214a7ba3fac60bd62faffa8615a4c7.setContent(html_c63153ab432f25fa314d7522d50a7334);
#
#
#
#         marker_251f6cade78b6b604342e03818ceeffb.bindPopup(popup_7f214a7ba3fac60bd62faffa8615a4c7)
#         ;
#
#
#
#
#             var marker_fd71489534adf5f19c0e42a5dea411c9 = L.marker(
#                 [37.94581445058187, -123.46925067901611],
#                 {}
#             ).addTo(map_0e40779e47dda69496df59b773841f4f);
#
#
#             var icon_12c816fde8ea16a22fed0d35605ed084 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_fd71489534adf5f19c0e42a5dea411c9.setIcon(icon_12c816fde8ea16a22fed0d35605ed084);
#
#
#         var popup_df86ed2c184d52dbb52195934473f1c8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0d1429aab863ce64e9c0af7e38638151 = $(`&lt;div id=&quot;html_0d1429aab863ce64e9c0af7e38638151&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Buoy_number: 29  Depth: deep&lt;/div&gt;`)[0];
#                 popup_df86ed2c184d52dbb52195934473f1c8.setContent(html_0d1429aab863ce64e9c0af7e38638151);
#
#
#
#         marker_fd71489534adf5f19c0e42a5dea411c9.bindPopup(popup_df86ed2c184d52dbb52195934473f1c8)
#         ;
#
#
#
#
#             var marker_9c2ab2eb8749afe625e32b9d8a7b1313 = L.marker(
#                 [46.857478085686175, -124.24454229018268],
#                 {}
#             ).addTo(map_0e40779e47dda69496df59b773841f4f);
#
#
#             var icon_febf56314b8394bdc5501f9500875949 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_9c2ab2eb8749afe625e32b9d8a7b1313.setIcon(icon_febf56314b8394bdc5501f9500875949);
#
#
#         var popup_dc880a23aecbcda680ed7e3a3d5cace7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1eef9a280f33c4fb73e957985dac5881 = $(`&lt;div id=&quot;html_1eef9a280f33c4fb73e957985dac5881&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Buoy_number: 36  Depth: intermediate&lt;/div&gt;`)[0];
#                 popup_dc880a23aecbcda680ed7e3a3d5cace7.setContent(html_1eef9a280f33c4fb73e957985dac5881);
#
#
#
#         marker_9c2ab2eb8749afe625e32b9d8a7b1313.bindPopup(popup_dc880a23aecbcda680ed7e3a3d5cace7)
#         ;
#
#
#
#
#             var marker_befff346d322704c0e8dcb3549907631 = L.marker(
#                 [33.21993983875621, -117.43944549560545],
#                 {}
#             ).addTo(map_0e40779e47dda69496df59b773841f4f);
#
#
#             var icon_1003e84006e23c4a96ad9fe3a83c0ef8 = L.AwesomeMarkers.icon(
#                 {&quot;extraClass

# %%
from geopy.distance import geodesic

chosen_deep_buoys = [67, 71, 157, 220, 222]
chosen_other_buoys = [43, 76, 158, 180, 201]

chosen_buoys = []
chosen_buoys.extend(chosen_deep_buoys[0:len(chosen_deep_buoys)])
chosen_buoys.extend(chosen_other_buoys[0:len(chosen_other_buoys)])

deep_buoys_lats = []
deep_buoys_longs = []
deep_buoys_depths = []

other_buoys_lats = []
other_buoys_longs = []
other_buoys_depths = []

for buoy in chosen_deep_buoys:
    index = np.where(buoy_info_array[:,0]==buoy)
    deep_buoys_lats.append(buoy_info_array[index,2])
    deep_buoys_longs.append(buoy_info_array[index,3])
    deep_buoys_depths.append(buoy_info_array[index,1])

deep_buoys_lats_array = np.asarray(deep_buoys_lats).reshape(len(chosen_deep_buoys),1)
deep_buoys_longs_array = np.asarray(deep_buoys_longs).reshape(len(chosen_deep_buoys),1)
deep_buoys_depths_array = np.asarray(deep_buoys_depths).reshape(len(chosen_deep_buoys),1)

for buoy in chosen_other_buoys:
    index = np.where(buoy_info_array[:,0]==buoy)
    other_buoys_lats.append(buoy_info_array[index,2])
    other_buoys_longs.append(buoy_info_array[index,3])
    other_buoys_depths.append(buoy_info_array[index,1])

other_buoys_lats_array = np.asarray(other_buoys_lats).reshape(len(chosen_other_buoys),1)
other_buoys_longs_array = np.asarray(other_buoys_longs).reshape(len(chosen_other_buoys),1)
other_buoys_depths_array = np.asarray(other_buoys_depths).reshape(len(chosen_other_buoys),1)

# %%
chosen_buoys_lats = []
chosen_buoys_longs = []
chosen_buoys_depths = []

for buoy in chosen_buoys:
    index = np.where(buoy_info_array[:,0]==buoy)
    chosen_buoys_lats.append(buoy_info_array[index,2])
    chosen_buoys_longs.append(buoy_info_array[index,3])
    chosen_buoys_depths.append(buoy_info_array[index,1])

chosen_buoys_lats_array = np.asarray(chosen_buoys_lats).reshape(len(chosen_buoys),1)
chosen_buoys_longs_array = np.asarray(chosen_buoys_longs).reshape(len(chosen_buoys),1)
chosen_buoys_depths_array = np.asarray(chosen_buoys_depths).reshape(len(chosen_buoys),1)

# %%
chosen_buoys
# Out:
# [67, 71, 157, 220, 222, 43, 76, 158, 180, 201]

# %%
buoy_locs = []
for i in range(len(chosen_buoys)):
    buoy_locs.append((chosen_buoys_lats_array[i], chosen_buoys_longs_array[i]))

distances = []
for i in range(len(chosen_buoys)):
    distance_buoy = []
    for j in range(len(chosen_buoys)):
        distance_buoy.append(geodesic(buoy_locs[i], buoy_locs[j]).kilometers)
    distances.append(distance_buoy)

distance_array = np.asarray(distances)

# %%
buoy_locs
# Out:
# [(array([33.22348254]), array([-119.86434146])),
#  (array([34.45973466]), array([-120.76592671])),
#  (array([36.33988825]), array([-122.10153707])),
#  (array([32.75078964]), array([-117.50024605])),
#  (array([34.75313339]), array([-121.56437683])),
#  (array([33.21993984]), array([-117.4394455])),
#  (array([35.20572633]), array([-120.85960447])),
#  (array([36.62627827]), array([-121.90707189])),
#  (array([37.75261688]), array([-122.83312988])),
#  (array([32.86888059]), array([-117.26633708]))]

# %%
buoy_locs_tuples = [(float(lat), float(lon)) for lat, lon in buoy_locs]
print(buoy_locs_tuples)
# Out:
# [(33.22348254067557, -119.86434146336146), (34.45973465659401, -120.76592670787464), (36.33988825480143, -122.10153706868488), (32.750789642333984, -117.50024604797365), (34.753133392333986, -121.56437683105467), (33.21993983875621, -117.43944549560545), (35.20572633009691, -120.85960446871243), (36.62627827037465, -121.9070718938654), (37.75261688232422, -122.8331298828125), (32.86888058980306, -117.26633707682292)]
# C:\Users\schakr18\AppData\Local\Temp\ipykernel_23248\2064586248.py:1: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   buoy_locs_tuples = [(float(lat), float(lon)) for lat, lon in buoy_locs]

# %%
distance_array
# Out:
# array([[  0.        , 160.51748503, 401.78197636, 227.0920759 ,
#         231.21077554, 226.04112128, 238.23969414, 421.09373357,
#         570.07530298, 245.82442832],
#        [160.51748503,   0.        , 241.31078253, 357.44525922,
#          80.14272528, 337.18165586,  83.20089931, 261.70022595,
#         410.0298873 , 369.40268448],
#        [401.78197636, 241.31078253,   0.        , 580.28578556,
#         182.66419826, 549.31999702, 168.65763129,  36.24423627,
#         169.75180941, 587.1812727 ],
#        [227.0920759 , 357.44525922, 580.28578556,   0.        ,
#         437.11046882,  52.34015662, 412.88721199, 589.67957634,
#         736.92947174,  25.52258301],
#        [231.21077554,  80.14272528, 182.66419826, 437.11046882,
#           0.        , 417.31344286,  81.62364218, 210.13315623,
#         351.814104  , 449.43189109],
#        [226.04112128, 337.18165586, 549.31999702,  52.34015662,
#         417.31344286,   0.        , 384.48290298, 556.1501087 ,
#         701.4928972 ,  42.15838312],
#        [238.23969414,  83.20089931, 168.65763129, 412.88721199,
#          81.62364218, 384.48290298,   0.        , 183.79758309,
#         333.37640779, 421.0055454 ],
#        [421.09373357, 261.70022595,  36.24423627, 589.67957634,
#         210.13315623, 556.1501087 , 183.79758309,   0.        ,
#         149.61921357, 595.09043951],
#        [570.07530298, 410.0298873 , 169.75180941, 736.92947174,
#         351.814104  , 701.4928972 , 333.37640779, 149.61921357,
#           0.        , 741.22844003],
#        [245.82442832, 369.40268448, 587.1812727 ,  25.52258301,
#         449.43189109,  42.15838312, 421.0055454 , 595.09043951,
#         741.22844003,   0.        ]])

# %%
import seaborn as sns
import matplotlib.pyplot as plt

distance_df = pd.DataFrame(distance_array)
distance_df.index = ['d1','d2','d3','d4','d5','s1','s2','s3','s4','s5']
distance_df.columns = ['d1','d2','d3','d4','d5','s1','s2','s3','s4','s5']

plt.rcParams["font.family"]="serif"
plt.figure(figsize=[9,8])
sns.heatmap(distance_df, annot=True, cmap='coolwarm', fmt='.2f')
plt.savefig("buoy_distances.png", dpi=225)
plt.show()

# %%
import statistics

# %%
sum_lats = []
sum_longs = []

for i in range(len(buoy_locs_tuples)):
    sum_lats.append(buoy_locs_tuples[i][0])
    sum_longs.append(buoy_locs_tuples[i][1])

map_center = [statistics.mean(sum_lats), statistics.mean(sum_longs)]

# %% [raw]
# map_center = [(buoy_locs[0][0] + buoy_locs[1][0] + buoy_locs[2][0] + buoy_locs[3][0] + buoy_locs[4][0]) / 5, \
#               (buoy_locs[0][1] + buoy_locs[1][1] + buoy_locs[2][1] + buoy_locs[3][1] + buoy_locs[4][1]) / 5]

# %%
map = folium.Map(location=map_center, zoom_start=7)

# Add markers for each point
for i in range(len(chosen_buoys)):
    if i <=4:
        color = 'darkblue'
    else:
        color = 'lightred'
    folium.Marker(location=buoy_locs[i],  
                icon=folium.Icon(color=color, icon='globe', size=(10,10)),
                popup=folium.Popup(f'Buoy_number: {chosen_buoys[i]}\n Depth: { float(chosen_buoys_depths[i])}', max_width = 300, parse_html=True),
            ).add_to(map)

for i in range(len(chosen_buoys)):
    if i <=4:
        entry = f'd{i+1}'
    else:
        entry = f's{i-4}'
    folium.Marker(location=buoy_locs[i],
                # popup=folium.Popup(f'Buoy_number: {chosen_deep_buoys[i]}\n Depth: { float(deep_buoys_depths[i])}', parse_html=True),
                icon=folium.DivIcon(
                    html=f'<div style="font-size: 12pt; color: black;">{entry}</div>'
                 )
            ).add_to(map)

# Add a line between the two points
for i in range(len(buoy_locs)-1):
    for j in range(i+1, len(buoy_locs)):
        folium.PolyLine([buoy_locs_tuples[i], buoy_locs_tuples[j]], color="blue"\
                        , weight=0.7, opacity=0.6, dash_array='5, 3').add_to(map)

# Add a popup showing the distance
# for i in range(distance_array.shape[0]-1):
#     for j in range(i+1, distance_array.shape[1]):
#         folium.Marker(
#             location=[(buoy_locs_tuples[i][0] + buoy_locs_tuples[j][0])/2, (buoy_locs_tuples[i][1] + buoy_locs_tuples[j][1])/2],
#             popup=f'Distance: {distance_array[i,j]:.2f} km',
#             icon=folium.DivIcon(
#                 html=f'<div style="font-size: 8pt; color: black;">{distance_array[i,j]:.2f} km</div>'
#             )
#         ).add_to(map)

# # Save the map to an HTML file or display it
map.save('all_water_buoys_with_distance.html')
# # To display in Jupyter Notebook, use:
map
# Out:
# C:\Users\schakr18\AppData\Local\Temp\ipykernel_22140\1205420540.py:11: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   popup=folium.Popup(f'Buoy_number: {chosen_buoys[i]}\n Depth: { float(chosen_buoys_depths[i])}', max_width = 300, parse_html=True),
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1309eaec211f7e25153916cf5f6b472c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1309eaec211f7e25153916cf5f6b472c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1309eaec211f7e25153916cf5f6b472c = L.map(
#                 &quot;map_1309eaec211f7e25153916cf5f6b472c&quot;,
#                 {
#                     center: [34.7200470398094, -120.2102016936768],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2fe0bb46d3277f1c56f7b1cf5387d3de = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_2fe0bb46d3277f1c56f7b1cf5387d3de.addTo(map_1309eaec211f7e25153916cf5f6b472c);
#
#
#             var marker_78327f9d23d9fd6a4541a2dea1763986 = L.marker(
#                 [33.22348254067557, -119.86434146336146],
#                 {}
#             ).addTo(map_1309eaec211f7e25153916cf5f6b472c);
#
#
#             var icon_27826ddb09409093953b702561eb2973 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;globe&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;darkblue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;, &quot;size&quot;: [10, 10]}
#             );
#             marker_78327f9d23d9fd6a4541a2dea1763986.setIcon(icon_27826ddb09409093953b702561eb2973);
#
#
#         var popup_7ca602d9e266caea90b936383fb0acd6 = L.popup({&quot;maxWidth&quot;: 300});
#
#
#
#                 var html_eb318464c9dc8c881cf8898a5e45f3c8 = $(`&lt;div id=&quot;html_eb318464c9dc8c881cf8898a5e45f3c8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Buoy_number: 67  Depth: 288.2850014822824&lt;/div&gt;`)[0];
#                 popup_7ca602d9e266caea90b936383fb0acd6.setContent(html_eb318464c9dc8c881cf8898a5e45f3c8);
#
#
#
#         marker_78327f9d23d9fd6a4541a2dea1763986.bindPopup(popup_7ca602d9e266caea90b936383fb0acd6)
#         ;
#
#
#
#
#             var marker_12299ccdb74be98cf40299a2f7454793 = L.marker(
#                 [34.45973465659401, -120.76592670787464],
#                 {}
#             ).addTo(map_1309eaec211f7e25153916cf5f6b472c);
#
#
#             var icon_0bc11f88f7dbea2f53da5e5b824a2a65 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;globe&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;darkblue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;, &quot;size&quot;: [10, 10]}
#             );
#             marker_12299ccdb74be98cf40299a2f7454793.setIcon(icon_0bc11f88f7dbea2f53da5e5b824a2a65);
#
#
#         var popup_67a0404e7cfda7ade3cc496594aa2d49 = L.popup({&quot;maxWidth&quot;: 300});
#
#
#
#                 var html_49e6543917eadd02d2e200eb0bcb0f45 = $(`&lt;div id=&quot;html_49e6543917eadd02d2e200eb0bcb0f45&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Buoy_number: 71  Depth: 476.3491023670544&lt;/div&gt;`)[0];
#                 popup_67a0404e7cfda7ade3cc496594aa2d49.setContent(html_49e6543917eadd02d2e200eb0bcb0f45);
#
#
#
#         marker_12299ccdb74be98cf40299a2f7454793.bindPopup(popup_67a0404e7cfda7ade3cc496594aa2d49)
#         ;
#
#
#
#
#             var marker_22998e13ce83daa93163f7d3badcf9a8 = L.marker(
#                 [36.33988825480143, -122.10153706868488],
#                 {}
#             ).addTo(map_1309eaec211f7e25153916cf5f6b472c);
#
#
#             var icon_1723840bcfd59aeb61f86fdc63e611ef = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;globe&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;darkblue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;, &quot;size&quot;: [10, 10]}
#             );
#             marker_22998e13ce83daa93163f7d3badcf9a8.setIcon(icon_1723840bcfd59aeb61f86fdc63e611ef);
#
#
#         var popup_5688bb625d2fe1a6145a898df7bb900a = L.popup({&quot;maxWidth&quot;: 300});
#
#
#
#                 var html_92d05457c66be77db54177de4f0e7f53 = $(`&lt;div id=&quot;html_92d05457c66be77db54177de4f0e7f53&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Buoy_number: 157  Depth: 367.0&lt;/div&gt;`)[0];
#                 popup_5688bb625d2fe1a6145a898df7bb900a.setContent(html_92d05457c66be77db54177de4f0e7f53);
#
#
#
#         marker_22998e13ce83daa93163f7d3badcf9a8.bindPopup(popup_5688bb625d2fe1a6145a898df7bb900a)
#         ;
#
#
#
#
#             var marker_a58f964f7f906a92c81902206e0c4060 = L.marker(
#                 [32.750789642333984, -117.50024604797365],
#                 {}
#             ).addTo(map_1309eaec211f7e25153916cf5f6b472c);
#
#
#             var icon_61bfe2251533df

# %%
color=[random.random(), random.random(), random.random()]
color
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 color=[random.random(), random.random(), random.random()]
#       2 color
#
# NameError: name 'random' is not defined

# %%
import folium


# Define the coordinates of the two points
point1 = (40.748817, -73.985428)  # Example: New York, USA (Latitude, Longitude)
point2 = (48.8566, 2.3522)        # Example: Paris, France (Latitude, Longitude)

# Calculate the distance between the points
distance = geodesic(point1, point2).kilometers

# Create a Folium map centered between the two points
map_center = [(point1[0] + point2[0]) / 2, (point1[1] + point2[1]) / 2]
map = folium.Map(location=map_center, zoom_start=4)

# Add markers for each point
folium.Marker(location=point1, popup='New York, USA').add_to(map)
folium.Marker(location=point2, popup='Paris, France').add_to(map)

# Add a line between the two points
folium.PolyLine([point1, point2], color='blue', weight=2.5, opacity=1).add_to(map)

# Add a popup showing the distance
folium.Marker(
    location=map_center,
    popup=f'Distance: {distance:.2f} km',
    icon=folium.DivIcon(
        html=f'<div style="font-size: 12pt; color: black;">Distance: {distance:.2f} km</div>'
    )
).add_to(map)

# Save the map to an HTML file or display it
map.save('map_with_distance.html')
# To display in Jupyter Notebook, use:
# map

# %%
import os
import IPython
import IPython.display
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import time
import math
from tensorflow import keras
import seaborn as sns
import random
import tensorflow as tf
from sklearn.metrics import confusion_matrix

# %%
def find_max_wave_height(zdisp_window):
    zero_crossings = np.where(np.diff(np.sign(zdisp_window)))[0]
    zero_crossings= np.append(zero_crossings, len(zdisp_window)-1);
    zero_crossings= np.append(-1,zero_crossings)
    h_wave=np.zeros(len(zero_crossings)-1)
    t_wave=np.zeros(len(zero_crossings)-1)
            
    for iter_zero_crossing in range(len(zero_crossings)-1):
        peak_idx=np.argmax(np.abs(zdisp_window[zero_crossings[iter_zero_crossing]+1:zero_crossings[iter_zero_crossing+1]+1]))
        h_wave[iter_zero_crossing]=zdisp_window[zero_crossings[iter_zero_crossing]+1+peak_idx]
        t_wave[iter_zero_crossing]=zero_crossings[iter_zero_crossing]+1+peak_idx
                
    max_wave_height=max(np.abs(np.diff(h_wave)))
    max_index = int(t_wave[np.argmax(np.abs(np.diff(h_wave)))])
    
    return max_wave_height, max_index

# %%
def populate_rw_arrays(dir, array, start_idx, end_idx):
    for folder in os.listdir(dir):
        print("Processing: " + folder)
        
        start_time = time.time()
        for file in os.listdir(dir+ "/" + folder):
            if file.endswith(".npz"):
                data=np.load(dir+"/"+ folder+"/"+file)
                z_tmp=data['zdisp'][start_idx:end_idx]
                #print(z_tmp.shape)
                significant_wave_height=4*np.std(data['zdisp'])#[start_idx:-1]
                #if folder=='Buoy_067':
                #    z_disp_rw_buoy_067.append(z_tmp/significant_wave_height)
                #else:
               # z_disp_rw.append(z_tmp/significant_wave_height) 
                z_disp_rw.append(z_tmp/significant_wave_height)
                #print(z_disp_rw[0].shape)
        print("--- %s seconds ---" % (time.time() - start_time))
    return

# %%
def populate_norw_arrays(dir, array, end_idx):
    for folder in os.listdir(dir):
        print("Processing: " + folder)
        
        start_time = time.time()
        for file in os.listdir(dir+ "/" + folder):
            if file.endswith(".npz"):
                data=np.load(dir+"/"+ folder+"/"+file)
                z_tmp=data['zdisp_norw'][0:end_idx]
                #print(z_tmp.shape)
                significant_wave_height=4*np.std(data['zdisp_norw'])#[start_idx:-1]
                #if folder=='Buoy_067':
                #    z_disp_rw_buoy_067.append(z_tmp/significant_wave_height)
                #else:
               # z_disp_rw.append(z_tmp/significant_wave_height) 
                z_disp_norw.append(z_tmp/significant_wave_height)

        print("--- %s seconds ---" % (time.time() - start_time))
    return

# %%
#num_samples_each_type = int(input("Enter the number of each type of wave sample: ")) 
#num_samples_each_type = 50000 

root_folder_rw = os.getcwd()+"/wave_height_g_2"
root_folder_norw = os.getcwd()+"/wave_height_g_2"

#root_folder="E:/"

window_start_min_rel_to_rw=-25
window_length_in_min=15

samplerate=1.28

rw_idx=round(25*60*samplerate)
start_idx=round((25+window_start_min_rel_to_rw)*60*samplerate)
end_idx=start_idx+round(window_length_in_min*60*samplerate)

rw_dir=root_folder_rw + '/rw_samples'
z_disp_rw=[] 
#z_disp_rw_buoy_067=[] 
populate_rw_arrays(rw_dir, z_disp_rw, start_idx, end_idx)

z_disp_norw=[]
#z_disp_norw_buoy_067=[]
norw_dir=root_folder_norw + '/norw_samples'
#norw_dir=root_folder_norw 
end_idx=end_idx-start_idx
populate_norw_arrays(norw_dir, z_disp_norw, end_idx)
# Out:
# Processing: Buoy_028
# --- 3.0887699127197266 seconds ---
# Processing: Buoy_029
# --- 5.3585591316223145 seconds ---
# Processing: Buoy_036
# --- 5.454762935638428 seconds ---
# Processing: Buoy_043
# --- 1.8132069110870361 seconds ---
# Processing: Buoy_045
# --- 3.483809232711792 seconds ---
# Processing: Buoy_067
# --- 3.6204705238342285 seconds ---
# Processing: Buoy_071
# --- 4.264028310775757 seconds ---
# Processing: Buoy_076
# --- 4.4311888217926025 seconds ---
# Processing: Buoy_081
# --- 0.0 seconds ---
# Processing: Buoy_087
# --- 0.0 seconds ---
# Processing: Buoy_088
# --- 0.0 seconds ---
# Processing: Buoy_089
# --- 0.0 seconds ---
# Processing: Buoy_090
# --- 0.0 seconds ---
# Processing: Buoy_091
# --- 0.4436163902282715 seconds ---
# Processing: Buoy_092
# --- 4.169417858123779 seconds ---
# Processing: Buoy_093
# --- 1.591048240661621 seconds ---
# Processing: Buoy_094
# --- 3.5101144313812256 seconds ---
# Processing: Buoy_095
# --- 0.8820486068725586 seconds ---
# Processing: Buoy_096
# --- 2.2645764350891113 seconds ---
# Processing: Buoy_097
# --- 0.0 seconds ---
# Processing: Buoy_098
# --- 4.498805284500122 seconds ---
# Processing: Buoy_099
# --- 0.0 seconds ---
# Processing: Buoy_100
# --- 3.576937437057495 seconds ---
# Processing: Buoy_101
# --- 0.3582601547241211 seconds ---
# Processing: Buoy_102
# --- 0.33451080322265625 seconds ---
# Processing: Buoy_103
# --- 0.046881675720214844 seconds ---
# Processing: Buoy_104
# --- 0.06251144409179688 seconds ---
# Processing: Buoy_105
# --- 0.04687929153442383 seconds ---
# Processing: Buoy_106
# --- 4.330066680908203 seconds ---
# Processing: Buoy_107
# --- 2.9752461910247803 seconds ---
# Processing: Buoy_109
# --- 0.046878814697265625 seconds ---
# Processing: Buoy_111
# --- 3.1042652130126953 seconds ---
# Processing: Buoy_113
# --- 0.1250009536743164 seconds ---
# Processing: Buoy_114
# --- 0.17629623413085938 seconds ---
# Processing: Buoy_115
# --- 0.2449796199798584 seconds ---
# Processing: Buoy_116
# --- 0.27594470977783203 seconds ---
# Processing: Buoy_117
# --- 0.06256341934204102 seconds ---
# Processing: Buoy_118
# --- 0.12501096725463867 seconds ---
# Processing: Buoy_121
# --- 4.708040714263916 seconds ---
# Processing: Buoy_122
# --- 0.21901369094848633 seconds ---
# Processing: Buoy_123
# --- 0.0315394401550293 seconds ---
# Processing: Buoy_124
# --- 0.21870088577270508 seconds ---
# Processing: Buoy_125
# --- 0.0666818618774414 seconds ---
# Processing: Buoy_126
# --- 0.12645411491394043 seconds ---
# Processing: Buoy_128
# --- 2.2788476943969727 seconds ---
# Processing: Buoy_129
# --- 0.03125 seconds ---
# Processing: Buoy_130
# --- 0.1250138282775879 seconds ---
# Processing: Buoy_131
# --- 0.18286347389221191 seconds ---
# Processing: Buoy_132
# --- 2.8015575408935547 seconds ---
# Processing: Buoy_133
# --- 0.26763153076171875 seconds ---
# Processing: Buoy_134
# --- 2.7932655811309814 seconds ---
# Processing: Buoy_135
# --- 0.015629053115844727 seconds ---
# Processing: Buoy_136
# --- 0.04687905311584473 seconds ---
# Processing: Buoy_138
# --- 0.4827251434326172 seconds ---
# Processing: Buoy_139
# --- 3.9845387935638428 seconds ---
# Processing: Buoy_141
# --- 0.10938453674316406 seconds ---
# Processing: Buoy_142
# --- 2.7958192825317383 seconds ---
# Processing: Buoy_143
# --- 2.6403281688690186 seconds ---
# Processing: Buoy_144
# --- 4.936356067657471 seconds ---
# Processing: Buoy_146
# --- 1.5617427825927734 seconds ---
# Processing: Buoy_147
# --- 2.923109531402588 seconds ---
# Processing: Buoy_148
# --- 0.031244277954101562 seconds ---
# Processing: Buoy_149
# --- 0.03125429153442383 seconds ---
# Processing: Buoy_150
# --- 2.764014720916748 seconds ---
# Processing: Buoy_151
# --- 0.05158042907714844 seconds ---
# Processing: Buoy_152
# --- 0.00946044921875 seconds ---
# Processing: Buoy_154
# --- 3.006411552429199 seconds ---
# Processing: Buoy_155
# --- 0.8983762264251709 seconds ---
# Processing: Buoy_156
# --- 2.3447437286376953 seconds ---
# Processing: Buoy_157
# --- 2.723565101623535 seconds ---
# Processing: Buoy_158
# --- 3.3527722358703613 seconds ---
# Processing: Buoy_160
# --- 3.624086380004883 seconds ---
# Processing: Buoy_161
# --- 0.5111885070800781 seconds ---
# Processing: Buoy_162
# --- 3.0961105823516846 seconds ---
# Processing: Buoy_163
# --- 1.5614781379699707 seconds ---
# Processing: Buoy_164
# --- 0.20936012268066406 seconds ---
# Processing: Buoy_165
# --- 0.9630997180938721 seconds ---
# Processing: Buoy_166
# --- 2.8423707485198975 seconds ---
# Processing: Buoy_167
# --- 0.6487350463867188 seconds ---
# Processing: Buoy_168
# --- 3.836019515991211 seconds ---
# Processing: Buoy_169
# --- 0.14063668251037598 seconds ---
# Processing: Buoy_170
# --- 0.3430948257446289 seconds ---
# Processing: Buoy_171
# --- 0.411013126373291 seconds ---
# Processing: Buoy_172
# --- 0.21450042724609375 seconds ---
# Processing: Buoy_174
# --- 0.29483532905578613 seconds ---
# Processing: Buoy_176
# --- 0.32904911041259766 seconds ---
# Processing: Buoy_179
# --- 2.374617099761963 seconds ---
# Processing: Buoy_180
# --- 0.4830758571624756 seconds ---
# Processing: Buoy_181
# --- 2.156813383102417 seconds ---
# Processing: Buoy_182
# --- 0.22359752655029297 seconds ---
# Processing: Buoy_184
# --- 0.01764392852783203 seconds ---
# Processing: Buoy_185
# --- 2.703395128250122 seconds ---
# Processing: Buoy_186
# --- 1.029503345489502 seconds ---
# Processing: Buoy_187
# --- 1.5165541172027588 seconds ---
# Processing: Buoy_188
# --- 2.7057394981384277 seconds ---
# Processing: Buoy_189
# --- 0.9443247318267822 seconds ---
# Processing: Buoy_190
# --- 0.41017675399780273 seconds ---
# Processing: Buoy_191
# --- 2.8304615020751953 seconds ---
# Processing: Buoy_192
# --- 1.9890263080596924 seconds ---
# Processing: Buoy_193
# --- 0.38141655921936035 seconds ---
# Processing: Buoy_194
# --- 0.8299648761749268 seconds ---
# Processing: Buoy_195
# --- 0.3049614429473877 seconds ---
# Processing: Buoy_196
# --- 1.9366803169250488 seconds ---
# Processing: Buoy_197
# --- 2.1421120166778564 seconds ---
# Processing: Buoy_198
# --- 2.1867575645446777 seconds ---
# Processing: Buoy_200
# --- 2.1845812797546387 seconds ---
# Processing: Buoy_201
# --- 2.079073190689087 seconds ---
# Processing: Buoy_202
# --- 0.9637713432312012 seconds ---
# Processing: Buoy_203
# --- 1.240086555480957 seconds ---
# Processing: Buoy_206
# --- 0.1542215347290039 seconds ---
# Processing: Buoy_207
# --- 0.3745725154876709 seconds ---
# Processing: Buoy_208
# --- 0.15666460990905762 seconds ---
# Processing: Buoy_209
# --- 1.951481580734253 seconds ---
# Processing: Buoy_210
# --- 0.7029600143432617 seconds ---
# Processing: Buoy_211
# --- 0.0937492847442627 seconds ---
# Processing: Buoy_212
# --- 0.22552180290222168 seconds ---
# Processing: Buoy_213
# --- 1.462407112121582 seconds ---
# Processing: Buoy_214
# --- 2.5932326316833496 seconds ---
# Processing: Buoy_215
# --- 1.4832439422607422 seconds ---
# Processing: Buoy_216
# --- 0.5793952941894531 seconds ---
# Processing: Buoy_217
# --- 1.5302190780639648 seconds ---
# Processing: Buoy_218
# --- 0.0 seconds ---
# Processing: Buoy_219
# --- 0.0 seconds ---
# Processing: Buoy_220
# --- 1.3148937225341797 seconds ---
# Processing: Buoy_222
# --- 1.52842378616333 seconds ---
# Processing: Buoy_223
# --- 0.0 seconds ---
# Processing: Buoy_224
# --- 0.7595498561859131 seconds ---
# Processing: Buoy_225
# --- 1.4786169528961182 seconds ---
# Processing: Buoy_226
# --- 2.0473127365112305 seconds ---
# Processing: Buoy_227
# --- 0.3010091781616211 seconds ---
# Processing: Buoy_228
# --- 0.30178403854370117 seconds ---
# Processing: Buoy_229
# --- 0.015639543533325195 seconds ---
# Processing: Buoy_231
# --- 0.345792293548584 seconds ---
# Processing: Buoy_232
# --- 0.41361045837402344 seconds ---
# Processing: Buoy_233
# --- 1.1899666786193848 seconds ---
# Processing: Buoy_234
# --- 0.19229698181152344 seconds ---
# Processing: Buoy_235
# --- 0.31185483932495117 seconds ---
# Processing: Buoy_236
# --- 1.0394103527069092 seconds ---
# Processing: Buoy_237
# --- 0.1254110336303711 seconds ---
# Processing: Buoy_238
# --- 0.8337521553039551 seconds ---
# Processing: Buoy_239
# --- 0.4694175720214844 seconds ---
# Processing: Buoy_240
# --- 0.9469759464263916 seconds ---
# Processing: Buoy_241
# --- 0.3755972385406494 seconds ---
# Processing: Buoy_242
# --- 0.04687786102294922 seconds ---
# Processing: Buoy_243
# --- 0.6916995048522949 seconds ---
# Processing: Buoy_244
# --- 1.18701171875 seconds ---
# Processing: Buoy_245
# --- 0.2162480354309082 seconds ---
# Processing: Buoy_246
# --- 0.031813859939575195 seconds ---
# Processing: Buoy_247
# --- 0.31076669692993164 seconds ---
# Processing: Buoy_252
# --- 0.0 seconds ---
# Processing: Buoy_254
# --- 0.0 seconds ---
# Processing: Buoy_255
# --- 0.16176557540893555 seconds ---
# Processing: Buoy_261
# --- 0.0 seconds ---
# Processing: Buoy_430
# --- 2.854281187057495 seconds ---
# Processing: Buoy_431
# --- 0.6622300148010254 seconds ---
# Processing: Buoy_432
# --- 0.2209775447845459 seconds ---
# Processing: Buoy_433
# --- 1.962810754776001 seconds ---
# Processing: Buoy_028
# --- 3.0461652278900146 seconds ---
# Processing: Buoy_029
# --- 5.529195785522461 seconds ---
# Processing: Buoy_036
# --- 5.639292478561401 seconds ---
# Processing: Buoy_043
# --- 1.8466756343841553 seconds ---
# Processing: Buoy_045
# --- 3.572822332382202 seconds ---
# Processing: Buoy_067
# --- 3.7509241104125977 seconds ---
# Processing: Buoy_071
# --- 4.49793553352356 seconds ---
# Processing: Buoy_076
# --- 4.685330629348755 seconds ---
# Processing: Buoy_081
# --- 0.0 seconds ---
# Processing: Buoy_087
# --- 0.0 seconds ---
# Processing: Buoy_088
# --- 0.0 seconds ---
# Processing: Buoy_089
# --- 0.0 seconds ---
# Processing: Buoy_090
# --- 0.0 seconds ---
# Processing: Buoy_091
# --- 0.5005855560302734 seconds ---
# Processing: Buoy_092
# --- 4.311138868331909 seconds ---
# Processing: Buoy_093
# --- 1.6419119834899902 seconds ---
# Processing: Buoy_094
# --- 3.622495651245117 seconds ---
# Processing: Buoy_095
# --- 0.9516525268554688 seconds ---
# Processing: Buoy_096
# --- 2.329047203063965 seconds ---
# Processing: Buoy_097
# --- 0.0026178359985351562 seconds ---
# Processing: Buoy_098
# --- 4.714414596557617 seconds ---
# Processing: Buoy_099
# --- 0.0 seconds ---
# Processing: Buoy_100
# --- 3.6700332164764404 seconds ---
# Processing: Buoy_101
# --- 0.3576340675354004 seconds ---
# Processing: Buoy_102
# --- 0.35095691680908203 seconds ---
# Processing: Buoy_103
# --- 0.04687905311584473 seconds ---
# Processing: Buoy_104
# --- 0.046878814697265625 seconds ---
# Processing: Buoy_105
# --- 0.06250548362731934 seconds ---
# Processing: Buoy_106
# --- 4.3365395069122314 seconds ---
# Processing: Buoy_107
# --- 3.015272855758667 seconds ---
# Processing: Buoy_109
# --- 0.03124547004699707 seconds ---
# Processing: Buoy_111
# --- 3.063339948654175 seconds ---
# Processing: Buoy_113
# --- 0.12500214576721191 seconds ---
# Processing: Buoy_114
# --- 0.1882951259613037 seconds ---
# Processing: Buoy_115
# --- 0.2542123794555664 seconds ---
# Processing: Buoy_116
# --- 0.2964439392089844 seconds ---
# Processing: Buoy_117
# --- 0.06249713897705078 seconds ---
# Processing: Buoy_118
# --- 0.10938382148742676 seconds ---
# Processing: Buoy_121
# --- 4.649170637130737 seconds ---
# Processing: Buoy_122
# --- 0.22968435287475586 seconds ---
# Processing: Buoy_123
# --- 0.030066251754760742 seconds ---
# Processing: Buoy_124
# --- 0.21621227264404297 seconds ---
# Processing: Buoy_125
# --- 0.051464080810546875 seconds ---
# Processing: Buoy_126
# --- 0.14061498641967773 seconds ---
# Processing: Buoy_128
# --- 2.286386489868164 seconds ---
# Processing: Buoy_129
# --- 0.031245708465576172 seconds ---
# Processing: Buoy_130
# --- 0.1369006633758545 seconds ---
# Processing: Buoy_131
# --- 0.1685934066772461 seconds ---
# Processing: Buoy_132
# --- 2.7836966514587402 seconds ---
# Processing: Buoy_133
# --- 0.26840925216674805 seconds ---
# Processing: Buoy_134
# --- 2.824751853942871 seconds ---
# Processing: Buoy_135
# --- 0.01561880111694336 seconds ---
# Processing: Buoy_136
# --- 0.046878814697265625 seconds ---
# Processing: Buoy_138
# --- 0.476564884185791 seconds ---
# Processing: Buoy_139
# --- 4.022380352020264 seconds ---
# Processing: Buoy_141
# --- 0.10989260673522949 seconds ---
# Processing: Buoy_142
# --- 2.758977174758911 seconds ---
# Processing: Buoy_143
# --- 2.661458969116211 seconds ---
# Processing: Buoy_144
# --- 4.936349153518677 seconds ---
# Processing: Buoy_146
# --- 1.5624358654022217 seconds ---
# Processing: Buoy_147
# --- 3.0295722484588623 seconds ---
# Processing: Buoy_148
# --- 0.03125309944152832 seconds ---
# Processing: Buoy_149
# --- 0.03125166893005371 seconds ---
# Processing: Buoy_150
# --- 2.7969260215759277 seconds ---
# Processing: Buoy_151
# --- 0.04680037498474121 seconds ---
# Processing: Buoy_152
# --- 0.03125309944152832 seconds ---
# Processing: Buoy_154
# --- 3.0363478660583496 seconds ---
# Processing: Buoy_155
# --- 0.9305641651153564 seconds ---
# Processing: Buoy_156
# --- 2.37491774559021 seconds ---
# Processing: Buoy_157
# --- 2.7855429649353027 seconds ---
# Processing: Buoy_158
# --- 3.3999521732330322 seconds ---
# Processing: Buoy_160
# --- 3.686756134033203 seconds ---
# Processing: Buoy_161
# --- 0.5212125778198242 seconds ---
# Processing: Buoy_162
# --- 3.164849042892456 seconds ---
# Processing: Buoy_163
# --- 1.530512809753418 seconds ---
# Processing: Buoy_164
# --- 0.20313382148742676 seconds ---
# Processing: Buoy_165
# --- 0.953254222869873 seconds ---
# Processing: Buoy_166
# --- 2.81231427192688 seconds ---
# Processing: Buoy_167
# --- 0.6301693916320801 seconds ---
# Processing: Buoy_168
# --- 3.822201728820801 seconds ---
# Processing: Buoy_169
# --- 0.15625977516174316 seconds ---
# Processing: Buoy_170
# --- 0.35814666748046875 seconds ---
# Processing: Buoy_171
# --- 0.4254631996154785 seconds ---
# Processing: Buoy_172
# --- 0.20035552978515625 seconds ---
# Processing: Buoy_174
# --- 0.31116747856140137 seconds ---
# Processing: Buoy_176
# --- 0.3278379440307617 seconds ---
# Processing: Buoy_179
# --- 2.437333345413208 seconds ---
# Processing: Buoy_180
# --- 0.48467135429382324 seconds ---
# Processing: Buoy_181
# --- 2.155795097351074 seconds ---
# Processing: Buoy_182
# --- 0.1938776969909668 seconds ---
# Processing: Buoy_184
# --- 0.032949209213256836 seconds ---
# Processing: Buoy_185
# --- 2.569657564163208 seconds ---
# Processing: Buoy_186
# --- 0.9683496952056885 seconds ---
# Processing: Buoy_187
# --- 1.4685838222503662 seconds ---
# Processing: Buoy_188
# --- 2.6394717693328857 seconds ---
# Processing: Buoy_189
# --- 0.8893575668334961 seconds ---
# Processing: Buoy_190
# --- 0.4007539749145508 seconds ---
# Processing: Buoy_191
# --- 2.6774892807006836 seconds ---
# Processing: Buoy_192
# --- 1.9226915836334229 seconds ---
# Processing: Buoy_193
# --- 0.36719346046447754 seconds ---
# Processing: Buoy_194
# --- 0.8347432613372803 seconds ---
# Processing: Buoy_195
# --- 0.3026313781738281 seconds ---
# Processing: Buoy_196
# --- 1.8673787117004395 seconds ---
# Processing: Buoy_197
# --- 2.1418569087982178 seconds ---
# Processing: Buoy_198
# --- 2.1707091331481934 seconds ---
# Processing: Buoy_200
# --- 2.186755895614624 seconds ---
# Processing: Buoy_201
# --- 2.0474517345428467 seconds ---
# Processing: Buoy_202
# --- 0.9823532104492188 seconds ---
# Processing: Buoy_203
# --- 1.2342746257781982 seconds ---
# Processing: Buoy_206
# --- 0.14067888259887695 seconds ---
# Processing: Buoy_207
# --- 0.37592315673828125 seconds ---
# Processing: Buoy_208
# --- 0.17188787460327148 seconds ---
# Processing: Buoy_209
# --- 1.9066553115844727 seconds ---
# Processing: Buoy_210
# --- 0.6778733730316162 seconds ---
# Processing: Buoy_211
# --- 0.09375786781311035 seconds ---
# Processing: Buoy_212
# --- 0.2299802303314209 seconds ---
# Processing: Buoy_213
# --- 1.4643659591674805 seconds ---
# Processing: Buoy_214
# --- 2.5619804859161377 seconds ---
# Processing: Buoy_215
# --- 1.4521822929382324 seconds ---
# Processing: Buoy_216
# --- 0.555413007736206 seconds ---
# Processing: Buoy_217
# --- 1.475661277770996 seconds ---
# Processing: Buoy_218
# --- 0.0 seconds ---
# Processing: Buoy_219
# --- 0.0 seconds ---
# Processing: Buoy_220
# --- 1.265535831451416 seconds ---
# Processing: Buoy_222
# --- 1.5161528587341309 seconds ---
# Processing: Buoy_223
# --- 0.0 seconds ---
# Processing: Buoy_224
# --- 0.7569479942321777 seconds ---
# Processing: Buoy_225
# --- 1.4465789794921875 seconds ---
# Processing: Buoy_226
# --- 2.076289415359497 seconds ---
# Processing: Buoy_227
# --- 0.30910706520080566 seconds ---
# Processing: Buoy_228
# --- 0.2844123840332031 seconds ---
# Processing: Buoy_229
# --- 0.031264543533325195 seconds ---
# Processing: Buoy_231
# --- 0.34596967697143555 seconds ---
# Processing: Buoy_232
# --- 0.3672659397125244 seconds ---
# Processing: Buoy_233
# --- 1.1717777252197266 seconds ---
# Processing: Buoy_234
# --- 0.20731782913208008 seconds ---
# Processing: Buoy_235
# --- 0.31129026412963867 seconds ---
# Processing: Buoy_236
# --- 1.0486488342285156 seconds ---
# Processing: Buoy_237
# --- 0.10938501358032227 seconds ---
# Processing: Buoy_238
# --- 0.8746628761291504 seconds ---
# Processing: Buoy_239
# --- 0.4696028232574463 seconds ---
# Processing: Buoy_240
# --- 0.9352686405181885 seconds ---
# Processing: Buoy_241
# --- 0.3705728054046631 seconds ---
# Processing: Buoy_242
# --- 0.046880245208740234 seconds ---
# Processing: Buoy_243
# --- 0.7226567268371582 seconds ---
# Processing: Buoy_244
# --- 1.188887357711792 seconds ---
# Processing: Buoy_245
# --- 0.23063969612121582 seconds ---
# Processing: Buoy_246
# --- 0.03116917610168457 seconds ---
# Processing: Buoy_247
# --- 0.3136286735534668 seconds ---
# Processing: Buoy_252
# --- 0.0 seconds ---
# Processing: Buoy_254
# --- 0.0 seconds ---
# Processing: Buoy_255
# --- 0.15634703636169434 seconds ---
# Processing: Buoy_261
# --- 0.018343687057495117 seconds ---
# Processing: Buoy_430
# --- 2.8584742546081543 seconds ---
# Processing: Buoy_431
# --- 0.6624248027801514 seconds ---
# Processing: Buoy_432
# --- 0.23138737678527832 seconds ---
# Processing: Buoy_433
# --- 1.9965813159942627 seconds ---

# %%
z_disp_rw=np.vstack(z_disp_rw)
#z_disp_rw_buoy_067=np.vstack(z_disp_rw_buoy_067)
print(z_disp_rw.shape)

z_disp_norw=np.vstack(z_disp_norw)
#z_disp_norw_buoy_067=np.vstack(z_disp_norw_buoy_067)

print(z_disp_norw.shape)
# Out:
# (169961, 1152)
# (169961, 1152)

# %%
possible_total_waves = round(z_disp_rw.shape[0] + z_disp_norw.shape[0])
print(f"Total possible waves in our study: {possible_total_waves}")
# Out:
# Total possible waves in our study: 339922

# %%
np.random.seed(5)  
len_array_rw = len(z_disp_rw) 
len_array_norw = len(z_disp_norw)

indices_rw_train = np.random.choice(len_array_rw, round(0.8*len_array_rw), replace=False)
indices_rw_test = [ind not in indices_rw_train for ind in range(0,len_array_rw)]

indices_norw_train = np.random.choice(len_array_norw, round(0.8*len_array_norw), replace=False)
indices_norw_test = [ind not in indices_norw_train for ind in range(0,len_array_norw)]

z_disp_rw_train = z_disp_rw[indices_rw_train]
labels_rw_train = np.ones(len(z_disp_rw_train))
z_disp_rw_test = z_disp_rw[indices_rw_test]
labels_rw_test = np.ones(len(z_disp_rw_test))

z_disp_norw_train = z_disp_norw[indices_norw_train]
labels_norw_train = np.zeros(len(z_disp_norw_train))
z_disp_norw_test = z_disp_norw[indices_norw_test]
labels_norw_test = np.zeros(len(z_disp_norw_test))

# %%
wave_data_train = np.concatenate((z_disp_rw_train, z_disp_norw_train), axis=0)
label_train = np.concatenate((labels_rw_train, labels_norw_train), axis=0)

idx = np.random.permutation(len(wave_data_train))
wave_data_train = wave_data_train[idx]
label_train=label_train[idx]

wave_data_test = np.concatenate((z_disp_rw_test, z_disp_norw_test), axis=0)
label_test = np.concatenate((labels_rw_test, labels_norw_test), axis=0)

idx_test = np.random.permutation(len(wave_data_test))
wave_data_test = wave_data_test[idx_test]
label_test=label_test[idx_test]

wave_data_train = wave_data_train.reshape((wave_data_train.shape[0], wave_data_train.shape[1], 1))
wave_data_test = wave_data_test.reshape((wave_data_test.shape[0], wave_data_test.shape[1], 1))

num_waves_total = len(wave_data_train)+len(wave_data_test)

print(f"The total number of wave samples in the case with relative rogue wave ratio 0.5 is {num_waves_total}.", end='\n')

np.savez(os.getcwd()  +'/DataPrepared2/RWs_H_g_2_tadv_10min_rw_smallWindow_0.5',wave_data_train=wave_data_train, wave_data_test=wave_data_test,label_train=label_train,label_test=label_test)
# Out:
# The total number of wave samples in the case with relative rogue wave ratio 0.5 is 339922.

# %%
print(label_train.shape)
print(wave_data_train.shape)
# Out:
# (271938,)
# (271938, 1152, 1)

# %%
relative_rw = [0.2, 0.3, 0.4, 0.6 ,0.7, 0.8]

for i in range(len(relative_rw)):
    ratio = relative_rw[i]
    if ratio >= 0.5:
        num_rw_train = z_disp_rw_train.shape[0]
        num_rw_test = z_disp_rw_test.shape[0]
        
        num_norw_train = round(((1-ratio)/ratio) * num_rw_train)
        num_norw_test = round(((1-ratio)/ratio) * num_rw_test)
    else:
        num_norw_train = z_disp_norw_train.shape[0]
        num_norw_test = z_disp_norw_test.shape[0]
        
        num_rw_train = round((ratio / (1-ratio))*num_norw_train)
        num_rw_test = round((ratio / (1-ratio))*num_norw_test)

    num_waves_total = num_norw_train + num_norw_test + num_rw_train + num_rw_test

    print(f"The number of training rogue wave samples in the case with relative rogue wave ratio {ratio} is {num_rw_train}.")
    print(f"The number of training non-rogue wave samples in the case with relative rogue wave ratio {ratio} is {num_norw_train}.")
    print(f"The number of testing rogue wave samples in the case with relative rogue wave ratio {ratio} is {num_rw_test}.")
    print(f"The number of testing non-rogue wave samples in the case with relative rogue wave ratio {ratio} is {num_norw_test}.")
    print(f"The total number of wave samples in the case with relative rogue wave ratio {ratio} is {num_waves_total}.", end='\n\n\n')

    np.random.seed(5)  
    len_array_rw_train = len(z_disp_rw_train) 
    len_array_norw_train = len(z_disp_norw_train)

    len_array_rw_test = len(z_disp_rw_test) 
    len_array_norw_test = len(z_disp_norw_test)

    indices_rw_train = np.random.choice(len_array_rw_train, num_rw_train, replace=False)
    indices_rw_test = np.random.choice(len_array_rw_test, num_rw_test, replace=False)

    indices_norw_train = np.random.choice(len_array_norw_train, num_norw_train, replace=False)
    indices_norw_test = np.random.choice(len_array_norw_test, num_norw_test, replace=False)

    z_disp_rw_train_altered = z_disp_rw_train[indices_rw_train]
    labels_rw_train_altered = np.ones(len(z_disp_rw_train_altered))
    z_disp_rw_test_altered = z_disp_rw_test[indices_rw_test]
    labels_rw_test_altered = np.ones(len(z_disp_rw_test_altered))

    z_disp_norw_train_altered = z_disp_norw_train[indices_norw_train]
    labels_norw_train_altered = np.zeros(len(z_disp_norw_train_altered))
    z_disp_norw_test_altered = z_disp_norw_test[indices_norw_test]
    labels_norw_test_altered = np.zeros(len(z_disp_norw_test_altered))

    # np.random.seed(5)  
    # len_array_rw = len(z_disp_rw) 
    # len_array_norw = len(z_disp_norw)

    # indices_rw = np.random.choice(len_array_rw, num_rw, replace=False) 
    # indices_norw = np.random.choice(len_array_norw, num_norw, replace=False)

    # z_disp_rw_altered = z_disp_rw[indices_rw] 
    # z_disp_norw_altered = z_disp_norw[indices_norw]

    wave_data_train = np.concatenate((z_disp_rw_train_altered, z_disp_norw_train_altered), axis=0)
    label_train = np.concatenate((labels_rw_train_altered, labels_norw_train_altered), axis=0)

    idx = np.random.permutation(len(wave_data_train))
    wave_data_train = wave_data_train[idx]
    label_train=label_train[idx]

    wave_data_test = np.concatenate((z_disp_rw_test_altered, z_disp_norw_test_altered), axis=0)
    label_test = np.concatenate((labels_rw_test_altered, labels_norw_test_altered), axis=0)

    idx_test = np.random.permutation(len(wave_data_test))
    wave_data_test = wave_data_test[idx_test]
    label_test=label_test[idx_test]

    wave_data_train = wave_data_train.reshape(wave_data_train.shape[0], wave_data_train.shape[1], 1)
    wave_data_test = wave_data_test.reshape(wave_data_test.shape[0], wave_data_test.shape[1], 1)

    print(label_train.shape)
    print(wave_data_train.shape)
    print(label_test.shape)
    print(wave_data_test.shape)

    np.savez(os.getcwd()  +f'/DataPrepared2/RWs_H_g_2_tadv_10min_rw_smallWindow_{relative_rw[i]}',wave_data_train=wave_data_train, wave_data_test=wave_data_test,label_train=label_train,label_test=label_test)
# Out:
# The number of training rogue wave samples in the case with relative rogue wave ratio 0.2 is 33992.
# The number of training non-rogue wave samples in the case with relative rogue wave ratio 0.2 is 135969.
# The number of testing rogue wave samples in the case with relative rogue wave ratio 0.2 is 8498.
# The number of testing non-rogue wave samples in the case with relative rogue wave ratio 0.2 is 33992.
# The total number of wave samples in the case with relative rogue wave ratio 0.2 is 212451.
#
#
# (169961,)
# (169961, 1152, 1)
# (42490,)
# (42490, 1152, 1)
# The number of training rogue wave samples in the case with relative rogue wave ratio 0.3 is 58272.
# The number of training non-rogue wave samples in the case with relative rogue wave ratio 0.3 is 135969.
# The number of testing rogue wave samples in the case with relative rogue wave ratio 0.3 is 14568.
# The number of testing non-rogue wave samples in the case with relative rogue wave ratio 0.3 is 33992.
# The total number of wave samples in the case with relative rogue wave ratio 0.3 is 242801.
#
#
# (194241,)
# (194241, 1152, 1)
# (48560,)
# (48560, 1152, 1)
# The number of training rogue wave samples in the case with relative rogue wave ratio 0.4 is 90646.
# The number of training non-rogue wave samples in the case with relative rogue wave ratio 0.4 is 135969.
# The number of testing rogue wave samples in the case with relative rogue wave ratio 0.4 is 22661.
# The number of testing non-rogue wave samples in the case with relative rogue wave ratio 0.4 is 33992.
# The total number of wave samples in the case with relative rogue wave ratio 0.4 is 283268.
#
#
# (226615,)
# (226615, 1152, 1)
# (56653,)
# (56653, 1152, 1)
# The number of training rogue wave samples in the case with relative rogue wave ratio 0.6 is 135969.
# The number of training non-rogue wave samples in the case with relative rogue wave ratio 0.6 is 90646.
# The number of testing rogue wave samples in the case with relative rogue wave ratio 0.6 is 33992.
# The number of testing non-rogue wave samples in the case with relative rogue wave ratio 0.6 is 22661.
# The total number of wave samples in the case with relative rogue wave ratio 0.6 is 283268.
#
#
# (226615,)
# (226615, 1152, 1)
# (56653,)
# (56653, 1152, 1)
# The number of training rogue wave samples in the case with relative rogue wave ratio 0.7 is 135969.
# The number of training non-rogue wave samples in the case with relative rogue wave ratio 0.7 is 58272.
# The number of testing rogue wave samples in the case with relative rogue wave ratio 0.7 is 33992.
# The number of testing non-rogue wave samples in the case with relative rogue wave ratio 0.7 is 14568.
# The total number of wave samples in the case with relative rogue wave ratio 0.7 is 242801.
#
#
# (194241,)
# (194241, 1152, 1)
# (48560,)
# (48560, 1152, 1)
# The number of training rogue wave samples in the case with relative rogue wave ratio 0.8 is 135969.
# The number of training non-rogue wave samples in the case with relative rogue wave ratio 0.8 is 33992.
# The number of testing rogue wave samples in the case with relative rogue wave ratio 0.8 is 33992.
# The number of testing non-rogue wave samples in the case with relative rogue wave ratio 0.8 is 8498.
# The total number of wave samples in the case with relative rogue wave ratio 0.8 is 212451.
#
#
# (169961,)
# (169961, 1152, 1)
# (42490,)
# (42490, 1152, 1)

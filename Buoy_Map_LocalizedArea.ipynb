# %%
import pandas as pd
import numpy as np
import folium

# %%
buoy_info = pd.read_csv("buoy_information.csv", header = None)

# %%
buoy_info.columns = ['buoy_name','depth','latitude','longitude']

# %%
buoy_info['buoy_name'] = buoy_info['buoy_name'].astype(int)

# %%
buoy_info.head(20)
# Out:
#     buoy_name       depth   latitude   longitude
# 0          28  366.501820  33.854929 -118.633477
# 1          29  549.913747  37.945814 -123.469251
# 2          36   40.146470  46.857478 -124.244542
# 3          43   20.000000  33.219940 -117.439445
# 4          45  225.587692  33.178806 -117.471486
# 5          67  288.285001  33.223483 -119.864341
# 6          71  476.349102  34.459735 -120.765927
# 7          76   25.496539  35.205726 -120.859604
# 8          81   53.000000  34.180000 -119.476669
# 9          87   35.000000  34.038334 -120.091667
# 10         88   55.000000  34.070000 -119.833336
# 11         89   55.000000  34.058334 -119.583336
# 12         90   61.000000  34.325001 -119.641670
# 13         91  182.352003  32.631844 -117.444068
# 14         92  432.135652  33.613898 -118.312238
# 15         93  188.968928  32.745832 -117.369096
# 16         94  328.042775  40.293043 -124.736832
# 17         95  180.011431  32.850571 -117.350999
# 18         96  369.750000  33.458447 -117.767031
# 19         97  120.000000  21.233334 -157.796661

# %%
buoy_info_array = np.asarray(buoy_info)

# %%
# buoy_info_array

# %%
us_center_latitude = 39.8281757358
us_center_longitude = -98.579500000

east_coast_focused_latitude = 40.71277600000
east_coast_focused_longitude = -74.005974000000

west_coast_focused_latitude = 37.77492900000
west_coast_focused_longitude = -122.41941800000


# Create a map centered at the given coordinates with a specific zoom level
# my_map = folium.Map(location=[us_center_latitude, us_center_longitude], zoom_start=5)  #### us center
# my_map = folium.Map(location=[east_coast_focused_latitude, east_coast_focused_longitude], zoom_start=5)  #### east coast center
my_map = folium.Map(location=[west_coast_focused_latitude, west_coast_focused_longitude], zoom_start=5)  #### west coast center

# List of coordinates
buoy_properties = []
for i in range(buoy_info_array.shape[0]):
    buoy_prop = (buoy_info_array[i][0], buoy_info_array[i][1], buoy_info_array[i][2], buoy_info_array[i][3])
    buoy_properties.append(buoy_prop)
    
# Add markers to the map
for entry in buoy_properties:
    
    buoy_num = entry[0]
    depth = entry[1]
    latitude = entry[2]
    longitude = entry[3]

    if depth < 20:
        color = "red"
        classification = "shallow"
    elif 20 <= depth <= 100:
        color = "orange"
        classification = "intermediate"
    else:
        color = "blue"
        classification = "deep"

    
    folium.Marker(
        location=[latitude, longitude],
        popup=folium.Popup(f'Buoy_number: {buoy_num.astype(int)}\n Depth: {classification}', parse_html=True),
        icon=folium.Icon(color=color)
    ).add_to(my_map)

# Save the map to an HTML file
my_map.save("west_coast_focused_buoys.html")

# %%
my_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f89c35e7074f8ac85f701016d925d645 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f89c35e7074f8ac85f701016d925d645&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f89c35e7074f8ac85f701016d925d645 = L.map(
#                 &quot;map_f89c35e7074f8ac85f701016d925d645&quot;,
#                 {
#                     center: [37.774929, -122.419418],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0d984fd9201baa9615bc7ef016efcefd = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_0d984fd9201baa9615bc7ef016efcefd.addTo(map_f89c35e7074f8ac85f701016d925d645);
#
#
#             var marker_8ea001f8dd15e1cde416de2160fdfbe4 = L.marker(
#                 [33.854928796941586, -118.6334772976962],
#                 {}
#             ).addTo(map_f89c35e7074f8ac85f701016d925d645);
#
#
#             var icon_4426a6efeed3fc1b0a5afb41820e597f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_8ea001f8dd15e1cde416de2160fdfbe4.setIcon(icon_4426a6efeed3fc1b0a5afb41820e597f);
#
#
#         var popup_06cdba6ffb7124c68ac23aa6850d390b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_90072d044ef751218b6c8ce5c583091c = $(`&lt;div id=&quot;html_90072d044ef751218b6c8ce5c583091c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Buoy_number: 28  Depth: deep&lt;/div&gt;`)[0];
#                 popup_06cdba6ffb7124c68ac23aa6850d390b.setContent(html_90072d044ef751218b6c8ce5c583091c);
#
#
#
#         marker_8ea001f8dd15e1cde416de2160fdfbe4.bindPopup(popup_06cdba6ffb7124c68ac23aa6850d390b)
#         ;
#
#
#
#
#             var marker_8b43dda5b6a13a82384ca3b934eb4516 = L.marker(
#                 [37.94581445058187, -123.46925067901611],
#                 {}
#             ).addTo(map_f89c35e7074f8ac85f701016d925d645);
#
#
#             var icon_8c1813691cc8484e8b7468a74dd931d4 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_8b43dda5b6a13a82384ca3b934eb4516.setIcon(icon_8c1813691cc8484e8b7468a74dd931d4);
#
#
#         var popup_d60a35f39dea1b8e1862cd0e55bd7a81 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_35e4d614c4261fad65697250744a0100 = $(`&lt;div id=&quot;html_35e4d614c4261fad65697250744a0100&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Buoy_number: 29  Depth: deep&lt;/div&gt;`)[0];
#                 popup_d60a35f39dea1b8e1862cd0e55bd7a81.setContent(html_35e4d614c4261fad65697250744a0100);
#
#
#
#         marker_8b43dda5b6a13a82384ca3b934eb4516.bindPopup(popup_d60a35f39dea1b8e1862cd0e55bd7a81)
#         ;
#
#
#
#
#             var marker_7703691d600e6b7f853b1d8e6b58d0dd = L.marker(
#                 [46.857478085686175, -124.24454229018268],
#                 {}
#             ).addTo(map_f89c35e7074f8ac85f701016d925d645);
#
#
#             var icon_986c94bc01b6e6c498f488d8b6bbb74f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_7703691d600e6b7f853b1d8e6b58d0dd.setIcon(icon_986c94bc01b6e6c498f488d8b6bbb74f);
#
#
#         var popup_78802fbb7815733b9882a8040c01ee6a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e18b13dc759472c6f9917e219a080ed6 = $(`&lt;div id=&quot;html_e18b13dc759472c6f9917e219a080ed6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Buoy_number: 36  Depth: intermediate&lt;/div&gt;`)[0];
#                 popup_78802fbb7815733b9882a8040c01ee6a.setContent(html_e18b13dc759472c6f9917e219a080ed6);
#
#
#
#         marker_7703691d600e6b7f853b1d8e6b58d0dd.bindPopup(popup_78802fbb7815733b9882a8040c01ee6a)
#         ;
#
#
#
#
#             var marker_9c95bba6582c9500b266e0d71231ccff = L.marker(
#                 [33.21993983875621, -117.43944549560545],
#                 {}
#             ).addTo(map_f89c35e7074f8ac85f701016d925d645);
#
#
#             var icon_61dbfd422bc119c1fe44b3c8cc654810 = L.AwesomeMarkers.icon(
#                 {&quot;extraClass

# %%
from geopy.distance import geodesic

chosen_deep_buoys = [67, 138, 167, 229, 234]
chosen_other_buoys = []

chosen_buoys = []
chosen_buoys.extend(chosen_deep_buoys[0:len(chosen_deep_buoys)])
chosen_buoys.extend(chosen_other_buoys[0:len(chosen_other_buoys)])

deep_buoys_lats = []
deep_buoys_longs = []
deep_buoys_depths = []

other_buoys_lats = []
other_buoys_longs = []
other_buoys_depths = []

for buoy in chosen_deep_buoys:
    index = np.where(buoy_info_array[:,0]==buoy)
    deep_buoys_lats.append(buoy_info_array[index,2])
    deep_buoys_longs.append(buoy_info_array[index,3])
    deep_buoys_depths.append(buoy_info_array[index,1])

deep_buoys_lats_array = np.asarray(deep_buoys_lats).reshape(len(chosen_deep_buoys),1)
deep_buoys_longs_array = np.asarray(deep_buoys_longs).reshape(len(chosen_deep_buoys),1)
deep_buoys_depths_array = np.asarray(deep_buoys_depths).reshape(len(chosen_deep_buoys),1)

for buoy in chosen_other_buoys:
    index = np.where(buoy_info_array[:,0]==buoy)
    other_buoys_lats.append(buoy_info_array[index,2])
    other_buoys_longs.append(buoy_info_array[index,3])
    other_buoys_depths.append(buoy_info_array[index,1])

other_buoys_lats_array = np.asarray(other_buoys_lats).reshape(len(chosen_other_buoys),1)
other_buoys_longs_array = np.asarray(other_buoys_longs).reshape(len(chosen_other_buoys),1)
other_buoys_depths_array = np.asarray(other_buoys_depths).reshape(len(chosen_other_buoys),1)

# %%
chosen_buoys_lats = []
chosen_buoys_longs = []
chosen_buoys_depths = []

for buoy in chosen_buoys:
    index = np.where(buoy_info_array[:,0]==buoy)
    chosen_buoys_lats.append(buoy_info_array[index,2])
    chosen_buoys_longs.append(buoy_info_array[index,3])
    chosen_buoys_depths.append(buoy_info_array[index,1])

chosen_buoys_lats_array = np.asarray(chosen_buoys_lats).reshape(len(chosen_buoys),1)
chosen_buoys_longs_array = np.asarray(chosen_buoys_longs).reshape(len(chosen_buoys),1)
chosen_buoys_depths_array = np.asarray(chosen_buoys_depths).reshape(len(chosen_buoys),1)

# %%
chosen_buoys
# Out:
# [67, 138, 167, 229, 234]

# %%
buoy_locs = []
for i in range(len(chosen_buoys)):
    buoy_locs.append((chosen_buoys_lats_array[i], chosen_buoys_longs_array[i]))

distances = []
for i in range(len(chosen_buoys)):
    distance_buoy = []
    for j in range(len(chosen_buoys)):
        distance_buoy.append(geodesic(buoy_locs[i], buoy_locs[j]).kilometers)
    distances.append(distance_buoy)

distance_array = np.asarray(distances)

# %%
buoy_locs
# Out:
# [(array([33.22348254]), array([-119.86434146])),
#  (array([33.40002823]), array([-119.65145874])),
#  (array([33.43467712]), array([-119.47433217])),
#  (array([33.17490005]), array([-118.96170044])),
#  (array([33.70000076]), array([-119.01000214]))]

# %%
buoy_locs_tuples = [(float(lat), float(lon)) for lat, lon in buoy_locs]
print(buoy_locs_tuples)
# Out:
# [(33.22348254067557, -119.86434146336146), (33.400028228759766, -119.65145874023436), (33.43467712402344, -119.47433217366536), (33.17490005493164, -118.96170043945312), (33.70000076293945, -119.01000213623045)]
# C:\Users\schakr18\AppData\Local\Temp\ipykernel_17800\2064586248.py:1: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   buoy_locs_tuples = [(float(lat), float(lon)) for lat, lon in buoy_locs]

# %%
distance_array
# Out:
# array([[ 0.        , 27.8640595 , 43.21115197, 84.33667906, 95.39971834],
#        [27.8640595 ,  0.        , 16.91695264, 68.93124533, 68.23273637],
#        [43.21115197, 16.91695264,  0.        , 55.76179501, 52.19930812],
#        [84.33667906, 68.93124533, 55.76179501,  0.        , 58.41304822],
#        [95.39971834, 68.23273637, 52.19930812, 58.41304822,  0.        ]])

# %%
import seaborn as sns
import matplotlib.pyplot as plt

distance_df = pd.DataFrame(distance_array)
distance_df.index = ['d1','d2','d3','d4','d5']
distance_df.columns = ['d1','d2','d3','d4','d5']

plt.rcParams["font.family"]="serif"
plt.figure(figsize=[9,8])
sns.heatmap(distance_df, annot=True, cmap='coolwarm', fmt='.2f')
plt.savefig("buoy_distances_localized.png", dpi=225)
plt.show()

# %%
import statistics

# %%
sum_lats = []
sum_longs = []

for i in range(len(buoy_locs_tuples)):
    sum_lats.append(buoy_locs_tuples[i][0])
    sum_longs.append(buoy_locs_tuples[i][1])

map_center = [statistics.mean(sum_lats), statistics.mean(sum_longs)]

# %% [raw]
# map_center = [(buoy_locs[0][0] + buoy_locs[1][0] + buoy_locs[2][0] + buoy_locs[3][0] + buoy_locs[4][0]) / 5, \
#               (buoy_locs[0][1] + buoy_locs[1][1] + buoy_locs[2][1] + buoy_locs[3][1] + buoy_locs[4][1]) / 5]

# %%
map = folium.Map(location=map_center, zoom_start=10)

# Add markers for each point
for i in range(len(chosen_buoys)):
    if i <=4:
        color = 'darkblue'
    else:
        color = 'lightred'
    folium.Marker(location=buoy_locs[i],  
                icon=folium.Icon(color=color, icon='globe', size=(10,10)),
                popup=folium.Popup(f'Buoy_number: {chosen_buoys[i]}\n Depth: { float(chosen_buoys_depths[i])}', max_width = 300, parse_html=True),
            ).add_to(map)

for i in range(len(chosen_buoys)):
    if i <=4:
        entry = f'd{i+1}'
    else:
        entry = f's{i-4}'
    folium.Marker(location=buoy_locs[i],
                # popup=folium.Popup(f'Buoy_number: {chosen_deep_buoys[i]}\n Depth: { float(deep_buoys_depths[i])}', parse_html=True),
                icon=folium.DivIcon(
                    html=f'<div style="font-size: 12pt; color: black;">{entry}</div>'
                 )
            ).add_to(map)

# Add a line between the two points
for i in range(len(buoy_locs)-1):
    for j in range(i+1, len(buoy_locs)):
        folium.PolyLine([buoy_locs_tuples[i], buoy_locs_tuples[j]], color="blue"\
                        , weight=0.7, opacity=0.6, dash_array='5, 3').add_to(map)

# Add a popup showing the distance
for i in range(distance_array.shape[0]-1):
    for j in range(i+1, distance_array.shape[1]):
        folium.Marker(
            location=[(buoy_locs_tuples[i][0] + buoy_locs_tuples[j][0])/2, (buoy_locs_tuples[i][1] + buoy_locs_tuples[j][1])/2],
            popup=f'Distance: {distance_array[i,j]:.2f} km',
            icon=folium.DivIcon(
                html=f'<div style="font-size: 12pt; color: black;">{distance_array[i,j]:.2f} km</div>'
            )
        ).add_to(map)

# # Save the map to an HTML file or display it
map.save('all_water_buoys_with_distance.html')
# # To display in Jupyter Notebook, use:
map
# Out:
# C:\Users\schakr18\AppData\Local\Temp\ipykernel_17800\4041662436.py:11: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   popup=folium.Popup(f'Buoy_number: {chosen_buoys[i]}\n Depth: { float(chosen_buoys_depths[i])}', max_width = 300, parse_html=True),
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4c6d6a4e3bc50d55bc9948ea37c835c0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4c6d6a4e3bc50d55bc9948ea37c835c0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4c6d6a4e3bc50d55bc9948ea37c835c0 = L.map(
#                 &quot;map_4c6d6a4e3bc50d55bc9948ea37c835c0&quot;,
#                 {
#                     center: [33.386617742265976, -119.39236699058895],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7c9d590b3543e067190ccbe8f0a3532e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_7c9d590b3543e067190ccbe8f0a3532e.addTo(map_4c6d6a4e3bc50d55bc9948ea37c835c0);
#
#
#             var marker_fb958fddcaeefd3878ca998a5cb79727 = L.marker(
#                 [33.22348254067557, -119.86434146336146],
#                 {}
#             ).addTo(map_4c6d6a4e3bc50d55bc9948ea37c835c0);
#
#
#             var icon_694c309754d2f99372d5405c789bde5a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;globe&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;darkblue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;, &quot;size&quot;: [10, 10]}
#             );
#             marker_fb958fddcaeefd3878ca998a5cb79727.setIcon(icon_694c309754d2f99372d5405c789bde5a);
#
#
#         var popup_34df5ba7922485c1a3f2ff280cb73024 = L.popup({&quot;maxWidth&quot;: 300});
#
#
#
#                 var html_8dc1442d2cd19db24b194170e959c2e7 = $(`&lt;div id=&quot;html_8dc1442d2cd19db24b194170e959c2e7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Buoy_number: 67  Depth: 288.2850014822824&lt;/div&gt;`)[0];
#                 popup_34df5ba7922485c1a3f2ff280cb73024.setContent(html_8dc1442d2cd19db24b194170e959c2e7);
#
#
#
#         marker_fb958fddcaeefd3878ca998a5cb79727.bindPopup(popup_34df5ba7922485c1a3f2ff280cb73024)
#         ;
#
#
#
#
#             var marker_043024864c4c0ade42665d286e1beab5 = L.marker(
#                 [33.400028228759766, -119.65145874023436],
#                 {}
#             ).addTo(map_4c6d6a4e3bc50d55bc9948ea37c835c0);
#
#
#             var icon_12b3889cc788a6d65864485044c8a3e9 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;globe&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;darkblue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;, &quot;size&quot;: [10, 10]}
#             );
#             marker_043024864c4c0ade42665d286e1beab5.setIcon(icon_12b3889cc788a6d65864485044c8a3e9);
#
#
#         var popup_1ec2d3359807820601e67e2e0a52a7a5 = L.popup({&quot;maxWidth&quot;: 300});
#
#
#
#                 var html_81578e655b61b8d351a946486a0b6c36 = $(`&lt;div id=&quot;html_81578e655b61b8d351a946486a0b6c36&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Buoy_number: 138  Depth: 105.0&lt;/div&gt;`)[0];
#                 popup_1ec2d3359807820601e67e2e0a52a7a5.setContent(html_81578e655b61b8d351a946486a0b6c36);
#
#
#
#         marker_043024864c4c0ade42665d286e1beab5.bindPopup(popup_1ec2d3359807820601e67e2e0a52a7a5)
#         ;
#
#
#
#
#             var marker_6980adde219667d8159c4a967fbcb41f = L.marker(
#                 [33.43467712402344, -119.47433217366536],
#                 {}
#             ).addTo(map_4c6d6a4e3bc50d55bc9948ea37c835c0);
#
#
#             var icon_a10f6b6f640089e01d25c50b95c72493 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;globe&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;darkblue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;, &quot;size&quot;: [10, 10]}
#             );
#             marker_6980adde219667d8159c4a967fbcb41f.setIcon(icon_a10f6b6f640089e01d25c50b95c72493);
#
#
#         var popup_70f86f1fc33e94333b74820a520a025d = L.popup({&quot;maxWidth&quot;: 300});
#
#
#
#                 var html_9a5fb702b383684595ddc7e81562b23b = $(`&lt;div id=&quot;html_9a5fb702b383684595ddc7e81562b23b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Buoy_number: 167  Depth: 1038.3333333333333&lt;/div&gt;`)[0];
#                 popup_70f86f1fc33e94333b74820a520a025d.setContent(html_9a5fb702b383684595ddc7e81562b23b);
#
#
#
#         marker_6980adde219667d8159c4a967fbcb41f.bindPopup(popup_70f86f1fc33e94333b74820a520a025d)
#         ;
#
#
#
#
#             var marker_d28b4281a0f16789205eb330be2e5de7 = L.marker(
#                 [33.17490005493164, -118.96170043945312],
#                 {}
#             ).addTo(map_4c6d6a4e3bc50d55bc9948ea37c835c0);
#
#
#             var icon_d4d39fdd

# %%
color=[random.random(), random.random(), random.random()]
color
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 color=[random.random(), random.random(), random.random()]
#       2 color
#
# NameError: name 'random' is not defined

# %%
import folium


# Define the coordinates of the two points
point1 = (40.748817, -73.985428)  # Example: New York, USA (Latitude, Longitude)
point2 = (48.8566, 2.3522)        # Example: Paris, France (Latitude, Longitude)

# Calculate the distance between the points
distance = geodesic(point1, point2).kilometers

# Create a Folium map centered between the two points
map_center = [(point1[0] + point2[0]) / 2, (point1[1] + point2[1]) / 2]
map = folium.Map(location=map_center, zoom_start=4)

# Add markers for each point
folium.Marker(location=point1, popup='New York, USA').add_to(map)
folium.Marker(location=point2, popup='Paris, France').add_to(map)

# Add a line between the two points
folium.PolyLine([point1, point2], color='blue', weight=2.5, opacity=1).add_to(map)

# Add a popup showing the distance
folium.Marker(
    location=map_center,
    popup=f'Distance: {distance:.2f} km',
    icon=folium.DivIcon(
        html=f'<div style="font-size: 12pt; color: black;">Distance: {distance:.2f} km</div>'
    )
).add_to(map)

# Save the map to an HTML file or display it
map.save('map_with_distance.html')
# To display in Jupyter Notebook, use:
# map
